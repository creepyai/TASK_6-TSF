# %% [markdown]
# # Author: VIVEK KUMAR NIGAM
# DATA SCIENCE & BUSINESS ANALYTICS @ TSF
# # GRIP_NOV'21 TASK_06

# %% [markdown]
# #  Prediction using Decision Tree Algorithm
# Decision Tree Classifier using Python

# %% [markdown]
#  Importing Libraries & Modules

# %%
# !pip install pydotplus

# %%
from matplotlib import pyplot as plt
from sklearn import datasets
from sklearn import tree
from sklearn.tree import DecisionTreeClassifier
import graphviz
from sklearn.tree import export_graphviz
import os
os.getcwd()
# Out:
# 'C:\\Users\\VIVEK\\Desktop\\TSF-INTERN'

# %%
os.chdir('C:\\Users\\VIVEK\\Desktop\\TSF-INTERN')
os.getcwd()
# Out:
# 'C:\\Users\\VIVEK\\Desktop\\TSF-INTERN'

# %%
from sklearn.datasets import load_iris

# %%
iris = load_iris()
x = iris.data
y = iris.target
tree_clf = DecisionTreeClassifier(random_state=10)
model = tree_clf.fit(x,y)

# %%
text_representation = tree.export_text(tree_clf)
print(text_representation)
# Out:
# |--- feature_3 <= 0.80
# |   |--- class: 0
# |--- feature_3 >  0.80
# |   |--- feature_3 <= 1.75
# |   |   |--- feature_2 <= 4.95
# |   |   |   |--- feature_3 <= 1.65
# |   |   |   |   |--- class: 1
# |   |   |   |--- feature_3 >  1.65
# |   |   |   |   |--- class: 2
# |   |   |--- feature_2 >  4.95
# |   |   |   |--- feature_3 <= 1.55
# |   |   |   |   |--- class: 2
# |   |   |   |--- feature_3 >  1.55
# |   |   |   |   |--- feature_0 <= 6.95
# |   |   |   |   |   |--- class: 1
# |   |   |   |   |--- feature_0 >  6.95
# |   |   |   |   |   |--- class: 2
# |   |--- feature_3 >  1.75
# |   |   |--- feature_2 <= 4.85
# |   |   |   |--- feature_0 <= 5.95
# |   |   |   |   |--- class: 1
# |   |   |   |--- feature_0 >  5.95
# |   |   |   |   |--- class: 2
# |   |   |--- feature_2 >  4.85
# |   |   |   |--- class: 2

# %%
with open("decistion_tree.log", "w") as fout:
    fout.write(text_representation)

# %%
fig = plt.figure(figsize=(25,20))
_ = tree.plot_tree(tree_clf, 
                   feature_names=iris.feature_names,  
                   class_names=iris.target_names,
                   filled=True)

# %%
prob_test = tree_clf.predict_proba([[7,3.1,4.2,1.1]])

# %%
print(prob_test)
# Out:
# [[0. 1. 0.]]

# %%
print('Thanks!')
# Out:
# Thanks!
